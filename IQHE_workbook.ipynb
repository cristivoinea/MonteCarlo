# %%
import numpy as np
import matplotlib.pyplot as plt
from utilities import Stats
from MonteCarloTorusSWAP import RunPSWAP, RunModSWAP, RunSignSWAP

# %%
Ne = 45
Ns = 45
M = 5000000
step_size = 0.062
t = 1j

RunModSWAP(Ne=Ne, Ns=Ns, t=t, M=M, M0=1e5, step_size=step_size, region_geometry='circle',
        boundary=0.28, state='laughlin', save_config=False, save_result=True)
# Out:
# Torus dimensions
# Lx =  16.814973649193785
# Ly =  16.814973649193785
# Iteration 250000 done, current acceptance ratio: 50.7 %
# Iteration 500000 done, current acceptance ratio: 50.66 %
# Iteration 750000 done, current acceptance ratio: 50.66 %
# Iteration 1000000 done, current acceptance ratio: 50.67 %
# Iteration 1250000 done, current acceptance ratio: 50.67 %
# Iteration 1500000 done, current acceptance ratio: 50.69 %
# Iteration 1750000 done, current acceptance ratio: 50.68 %
# Iteration 2000000 done, current acceptance ratio: 50.71 %
# Iteration 2250000 done, current acceptance ratio: 50.71 %
# Iteration 2500000 done, current acceptance ratio: 50.71 %
# Iteration 2750000 done, current acceptance ratio: 50.69 %
# Iteration 3000000 done, current acceptance ratio: 50.7 %
# Iteration 3250000 done, current acceptance ratio: 50.7 %
# Iteration 3500000 done, current acceptance ratio: 50.69 %
# Iteration 3750000 done, current acceptance ratio: 50.69 %
# ...

# %%
Ne = 45
Ns = 45
M = 10000000
step_size = 0.062
t = 1j

boundaries = np.arange(0.30, 0.381, 0.01)
for bd in boundaries:
        RunModSWAP(Ne=Ne, Ns=Ns, t=t, M=M, M0=5e5, step_size=step_size, region_geometry='circle',
        boundary=bd, state='laughlin', save_config=True, save_result=True)
# Out:
# Torus dimensions
# Lx =  16.814973649193785
# Ly =  16.814973649193785
# Iteration 500000 done, current acceptance ratio: 50.62 %
# Iteration 1000000 done, current acceptance ratio: 50.61 %
# Iteration 1500000 done, current acceptance ratio: 50.66 %
# Iteration 2000000 done, current acceptance ratio: 50.68 %
# Iteration 2500000 done, current acceptance ratio: 50.64 %
# Iteration 3000000 done, current acceptance ratio: 50.63 %
# Iteration 3500000 done, current acceptance ratio: 50.63 %
# Iteration 4000000 done, current acceptance ratio: 50.62 %
# Iteration 4500000 done, current acceptance ratio: 50.63 %
# Iteration 5000000 done, current acceptance ratio: 50.64 %
# Iteration 5500000 done, current acceptance ratio: 50.64 %
# Iteration 6000000 done, current acceptance ratio: 50.64 %
# Iteration 6500000 done, current acceptance ratio: 50.65 %
# Iteration 7000000 done, current acceptance ratio: 50.65 %
# Iteration 7500000 done, current acceptance ratio: 50.64 %
# ...

# %%
Ne = 45
Ns = 45
M = 10000000
step_size = 0.062
t = 1j

boundaries = np.arange(0.30, 0.381, 0.01)
for bd in boundaries:
        RunSignSWAP(Ne=Ne, Ns=Ns, t=t, M=M, M0=5e5, step_size=step_size, region_geometry='circle',
        boundary=bd, state='laughlin', save_config=True, save_result=True)
# Out:
# Torus dimensions
# Lx =  16.814973649193785
# Ly =  16.814973649193785
# Iteration 500000 done, current acceptance ratio: 51.03 %
# Iteration 1000000 done, current acceptance ratio: 51.09 %
# Iteration 1500000 done, current acceptance ratio: 51.04 %
# Iteration 2000000 done, current acceptance ratio: 51.08 %
# Iteration 2500000 done, current acceptance ratio: 51.08 %
# Iteration 3000000 done, current acceptance ratio: 51.09 %
# Iteration 3500000 done, current acceptance ratio: 51.11 %
# Iteration 4000000 done, current acceptance ratio: 51.11 %
# Iteration 4500000 done, current acceptance ratio: 51.11 %
# Iteration 5000000 done, current acceptance ratio: 51.11 %
# Iteration 5500000 done, current acceptance ratio: 51.11 %
# Iteration 6000000 done, current acceptance ratio: 51.12 %
# Iteration 6500000 done, current acceptance ratio: 51.13 %
# Iteration 7000000 done, current acceptance ratio: 51.12 %
# Iteration 7500000 done, current acceptance ratio: 51.13 %
# ...
