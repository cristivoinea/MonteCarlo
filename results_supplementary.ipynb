pair_amps[12] = np.array([-3.9979037389485e-18, 0.00085874566325326, 3.798128694978e-18,   0.38283566427845, -1.7016332398941e-18, 0.30174204804788,  7.9152399543167e-18, 0.22326961888751, -8.0187266111292e-18, 0.21379892923837, 4.1296495773342e-18, 0.23437572857303, -5.3573378075956e-18, 0.25622266528894, 1.3522881002915e-18,  0.26494025445954, 0, 0.26077821420013, -3.1170812458958e-18, 0.25128271245987, -5.0957502106819e-18, 0.24354719083406, 0, 0.24074630150101,-8.673617379884e-19,  0.24270363977619, 0, 0.24777516959394, 3.4694469519536e-18,  0.25395237774313, 0, 0.25919872502016,-1.7347234759768e-18, 0.26180795395408])
pair_amps[13] = np.array([4.7892720386071e-18, 0.00087503831198624, 3.5239476288745e-18,   0.37656739326463, -1.69603951022e-18,   0.30019699547531,  3.8210819405978e-18, 0.22324198065754,  5.1695379916739e-18, 0.21234998240654,-1.7394441181845e-18, 0.23144449283372, -3.608890578076e-18, 0.25235848085931, 6.2820727928707e-18,  0.26133914433067, 0, 0.25852327408926, -3.1170812458958e-18, 0.25049680990828, -5.0957502106819e-18, 0.24340996362167, 0, 0.24010116583027,-8.673617379884e-19,  0.2405385562865,  0, 0.2433872649118,  3.4694469519536e-18,  0.24718297121533, 0, 0.25081903220865,-1.7347234759768e-18, 0.25361937822293, 0, 0.25524768416951, 0])


for n in ns:
    degeneracies[n] = (2*(3*(n-1)-np.arange(pair_amps[n].size))+1)/n
    structure_factors[n] = degeneracies[n]*pair_amps[n]

    plt.scatter(np.arange(structure_factors[n].size), structure_factors[n], marker='x')

# %%
n = 170
s = 0
for i in range(51, n, 2):
    s += (gamma(i+1/2)/(2*gamma(i+1)))*(2/9)*(2*(3*(n-1)-i)+1)/n

print(s)
# Out:
# 3.142512116350161

# %%
poly_deg = 1
ds = np.zeros(26)
x_fit = np.arange(0, 0.175, 0.01)

for i in range(1,16,2):
    popt, pcov = np.polyfit(1/ns, [structure_factors[n][i] for n in ns], deg=poly_deg, cov=True)
    ds[i] = popt[poly_deg]
    
    plt.scatter(1/ns, [structure_factors[n][i] for n in ns], label=f'$d_{i}$')
    y_fit = np.zeros(x_fit.size)
    for i in range(poly_deg+1):
        y_fit += popt[i]*(x_fit)**(poly_deg-i)
    plt.plot(x_fit, y_fit)


for i in range(17,26,2):
    popt, pcov = np.polyfit(1/ns[(i-15)//2:], [structure_factors[n][i] for n in ns[(i-15)//2:]], deg=poly_deg, cov=True)
    ds[i] = popt[poly_deg]

    plt.scatter(1/ns[(i-15)//2:], [structure_factors[n][i] for n in ns[(i-15)//2:]], label=f'$d_{i}$')
    y_fit = np.zeros(x_fit.size)
    for i in range(poly_deg+1):
        y_fit += popt[i]*(x_fit)**(poly_deg-i)
    plt.plot(x_fit, y_fit)

# %%
from scipy.special import gamma
gs_approx = 0
for i in range(ds.size):
    gs_approx += ds[i]*gamma(i+1/2)/(2*gamma(i+1))

print(f"GS energy approximation = {gs_approx}")
# Out:
# GS energy approximation = 2.7692550705225827

# %%
gs_energy = np.array([7.7432698280425, 10.121045415564, 12.725298638045, 15.542042784237, 18.559733276244, 21.7683505299, 25.159034553539, 28.72433790166])
ns = np.arange(6, 14)
deg = 1
gs_th = np.polyfit(1/ns, gs_energy/ns, deg=deg)
print(gs_th[deg])

plt.scatter(1/ns, gs_energy/ns)
# Out:
# 2.9155487300728082

# %%
import matplotlib as mpl
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.legend_handler import HandlerTuple
def update_mpl_param(axeslabel, legend, xtick, ytick):
    pgf_with_latex = {                      # setup matplotlib to use latex for output
        "pgf.texsystem": "pdflatex",        # change this if using xetex or lautex
        "text.usetex": True,                # use LaTeX to write all text
        "font.family": "serif",
        "font.serif": [],                   # blank entries should cause plots 
        "font.sans-serif": [],              # to inherit fonts from the document
        "font.monospace": [],
        "axes.labelsize": axeslabel,               # LaTeX default is 10pt font.
        "font.size": 14,
        "legend.fontsize": legend,               # Make the legend/label fonts 
        "xtick.labelsize": xtick,               # a little smaller
        "ytick.labelsize": ytick,    # default fig size of 0.9 textwidth
        "pgf.preamble": "\n".join([ # plots will use this preamble
            ])
        }
    mpl.rcParams.update(pgf_with_latex)

update_mpl_param(18,16,14,14)

# %% [markdown]
# ## Projected vs Unprojected

# %%
x_cfl2, entropy_cfl2 = LoadEntropy(37, 37, 10e6, 1e5, 1j, 0.072, 'circle', 'cfl1')
x_cfl0, entropy_cfl0 = LoadEntropy(37, 37, 5e6, 1e5, 1j, 0.04, 'circle', 'cfl0')
x_ff, entropy_ff = LoadEntropy(37, 74, 15e6, 1e5, 1j, 0.051, 'circle', 'free_fermions')

popt_cfl2, pcov_cfl2 = np.polyfit(np.log(x_cfl2), entropy_cfl2[:,6]/x_cfl2, deg=1, cov=True, w=1/entropy_cfl2[:,7])
popt_sign_cfl2, pcov_sign_cfl2 = np.polyfit(np.log(x_cfl2), entropy_cfl2[:,4]/x_cfl2, deg=1, cov=True, w=1/entropy_cfl2[:,5])

x_fit = np.linspace(0,5,2)
y_fit_cfl2 = x_fit*popt_cfl2[0] + popt_cfl2[1]
y_fit_sign_cfl2 = x_fit*popt_sign_cfl2[0] + popt_sign_cfl2[1]

popt_cfl0, pcov_cfl0 = np.polyfit(np.log(x_cfl0), entropy_cfl0[:,6]/x_cfl0, deg=1, cov=True, w=1/entropy_cfl0[:,7])
popt_sign_cfl0, pcov_sign_cfl0 = np.polyfit(np.log(x_cfl0), entropy_cfl0[:,4]/x_cfl0, deg=1, cov=True, w=1/entropy_cfl0[:,5])

x_fit = np.linspace(0,5,2)
y_fit_cfl0 = x_fit*popt_cfl0[0] + popt_cfl0[1]
y_fit_sign_cfl0 = x_fit*popt_sign_cfl0[0] + popt_sign_cfl0[1]

popt_ff, pcov_ff = np.polyfit(np.log(x_ff), entropy_ff[:,6]/x_ff, deg=1, cov=True, w=1/entropy_ff[:,7])
popt_sign_ff, pcov_sign_ff = np.polyfit(np.log(x_ff), entropy_ff[:,4]/x_ff, deg=1, cov=True, w=1/entropy_ff[:,5])

x_fit = np.linspace(0,5,2)
y_fit_ff = x_fit*popt_ff[0] + popt_ff[1]
y_fit_sign_ff = x_fit*popt_sign_ff[0] + popt_sign_ff[1]

# %%
Ne = 37
update_mpl_param(16,14,12,12)

plt.errorbar(np.log(x_ff), (entropy_ff[:,6]/x_ff), entropy_ff[:,7], marker='x',
             color='black', markersize=6, capsize=5, linestyle='none', markerfacecolor='none',
             label=f'free fermions \n $\\kappa = {popt_ff[0]:.3f} \pm {np.sqrt(pcov_ff[0,0]):.3f}$')

plt.errorbar(np.log(x_cfl0), (entropy_cfl0[:,6]/x_cfl0), entropy_cfl0[:,7], marker='s',
             color='red', markersize=6, capsize=5, linestyle='none', markerfacecolor='none',
            label=f'$\\nu = 1$ CFL unproj. \n $\\kappa = {popt_cfl0[0]:.3f} \pm {np.sqrt(pcov_cfl0[0,0]):.3f}$')
plt.errorbar(np.log(x_cfl2), (entropy_cfl2[:,6]/x_cfl2), entropy_cfl2[:,7], marker='x',
             color='blue', markersize=6, capsize=5, linestyle='none', markerfacecolor='none',
             label=f'$\\nu = 1$ CFL proj.\n $\\kappa = {popt_cfl2[0]:.3f} \pm {np.sqrt(pcov_cfl2[0,0]):.3f}$')

plt.plot(x_fit, y_fit_cfl0, '--', c='gray')
plt.plot(x_fit, y_fit_cfl2, '--', c='gray')
plt.plot(x_fit, y_fit_ff, '--', c='gray')

#plt.plot(x_fit, y_fit_ff22, '--', c='gray')

plt.legend(ncol=2)
plt.ylabel('$S_{2}/\\lambda$')
plt.xlabel('$\ln \\lambda$')
plt.xlim(0.5,1.9)
plt.ylim(0.6,2.3)
#plt.title('$S_{2, \mathrm{tot}}$'+f', $N={Ne}$ ')
plt.tight_layout(pad=0.5)
plt.savefig(f'entropy v=1 unproj.pdf')

# %%
update_mpl_param(16,14,12,12)
fig, ax = plt.subplots(1,3, figsize=(9,5))
#fig.suptitle(f'Renyi entropy decomposition $S_2$, $N={Ne}$ ')


ax[0].errorbar(np.log(x_cfl0), (entropy_cfl0[:,0]/x_cfl0), entropy_cfl0[:,1], marker='x',
             color='red', markersize=6, capsize=5, linestyle='none', markerfacecolor='none',
             label='$\\nu=1$ unproj.')
ax[0].errorbar(np.log(x_cfl2), (entropy_cfl2[:,0]/x_cfl2), entropy_cfl2[:,1], marker='x',
             color='blue', markersize=6, capsize=5, linestyle='none', markerfacecolor='none',
             label='$\\nu=1$ proj.')
ax[0].errorbar(np.log(x_ff), (entropy_ff[:,0]/x_ff), entropy_ff[:,1], marker='x',
             color='black', markersize=6, capsize=5, linestyle='none', markerfacecolor='none',
             label='free fermions')
ax[0].legend()
ax[0].set_xlabel('$\ln \\lambda$')
ax[0].set_ylabel('$S_{2}/\lambda$')
ax[0].text(1.6,0.35,'p', fontsize=16)
#ax[0].set_xlim(0.5,1.85)
#ax[0].set_ylim(0.2,0.6)
#ax[0].set_title('$S_{2, \mathrm{p}}$')


ax[1].errorbar(np.log(x_ff), (entropy_ff[:,2]/x_ff), entropy_ff[:,3], marker='x',
             color='black', markersize=6, capsize=5, linestyle='none', markerfacecolor='none')
ax[1].errorbar(np.log(x_cfl0), (entropy_cfl0[:,2]/x_cfl0), entropy_cfl0[:,3], marker='x',
             color='red', markersize=6, capsize=5, linestyle='none', markerfacecolor='none')
#ax[0].plot(x_fit, y_fit_p_cfl, '--', c='tab:blue')
ax[1].errorbar(np.log(x_cfl2), (entropy_cfl2[:,2]/x_cfl2), entropy_cfl2[:,3], marker='x',
             color='blue', markersize=6, capsize=5, linestyle='none', markerfacecolor='none')

#ax[1].legend()
ax[1].set_xlabel('$\ln \\lambda$')
ax[1].text(1.2,0.4,'mod', fontsize=16)
#ax[1].set_title('$S_{2, \mathrm{mod}}$')
#ax[1].set_xlim(0.5,1.85)
#ax[1].set_ylim(0.1,1)



ax[2].errorbar(np.log(x_ff), (entropy_ff[:,4]/x_ff), entropy_ff[:,5], marker='x',
             color='black', markersize=6, capsize=5, linestyle='none', markerfacecolor='none')
ax[2].errorbar(np.log(x_cfl0), (entropy_cfl0[:,4]/x_cfl0), entropy_cfl0[:,5], marker='x',
             color='red', markersize=6, capsize=5, linestyle='none', markerfacecolor='none')
ax[2].plot(x_fit, y_fit_sign_cfl2, '--', c='tab:blue', label=f'$\\kappa = {popt_sign_cfl2[0]:.3f} \pm {np.sqrt(pcov_sign_cfl2[0,0]):.3f}$')
ax[2].plot(x_fit, y_fit_sign_ff, '--', c='tab:gray', label=f'$\\kappa = {popt_sign_ff[0]:.3f} \pm {np.sqrt(pcov_sign_ff[0,0]):.3f}$')
ax[2].plot(x_fit, y_fit_sign_cfl0, '--', c='tab:red', label=f'$\\kappa = {popt_sign_cfl0[0]:.3f} \pm {np.sqrt(pcov_sign_cfl0[0,0]):.3f}$')
ax[2].errorbar(np.log(x_cfl2), (entropy_cfl2[:,4]/x_cfl2), entropy_cfl2[:,5], marker='x',
             color='blue', markersize=6, capsize=5, linestyle='none', markerfacecolor='none')

ax[2].legend(loc='upper right')
ax[2].set_xlabel('$\ln \\lambda$')
ax[2].text(1.1,0.55,'sign', fontsize=16)
ax[2].set_xlim(0.5,1.85)
ax[2].set_ylim(0.,0.8)
#ax[2].set_title('$S_{2, \mathrm{sign}}$')
plt.tight_layout(pad=0.5)

plt.savefig(f'entropy decomposition v=1 unproj.pdf')
