# %%
import numpy as np
import matplotlib.pyplot as plt
from utilities import fermi_sea_kx, fermi_sea_ky

# %%
kxs = fermi_sea_kx[37]
kys = fermi_sea_ky[37]

# %%
x, y = np.meshgrid(np.arange(-5,5.1,1), np.arange(-5,5.1,1))

# %%
fig, ax = plt.subplots(1, figsize=(5,5))

ax.scatter(kxs, kys)

ax.scatter(0,0, s=15, color='k')
ax.scatter(x,y, s=15, marker='x')
circle = plt.Circle((0,0), np.sqrt(17), edgecolor='red', facecolor='none')
ax.add_patch(circle)
